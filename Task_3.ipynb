# %% [markdown]
# #### A.  Using the mathematical representations that you developed in Task 2, write a program in either Python or R to solve the optimization problem computationally.

# %%
from pulp import *
import numpy as np
import pandas as pd
import seaborn as sns

# %%
hubs = pd.read_excel("Task3.xlsx", sheet_name="Hubs")
centers = pd.read_excel("Task3.xlsx", sheet_name="Centers")
focus = pd.read_excel("Task3.xlsx", sheet_name="Focus Cities")
cost = pd.read_excel("Task3.xlsx", sheet_name="Cost")
